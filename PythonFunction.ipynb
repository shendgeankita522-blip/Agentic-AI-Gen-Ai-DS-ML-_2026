# %%
def greet():
    print('hello')
    print('good morning team')

# %%
def greet():
    print('hello')
    print('good morning team')
greet()
# Out:
# hello
# good morning team

# %%
def greet():
    print('hello')
    print('good morning team')
greet()

def greet():
    print('hello')
    print('good morning team')
greet()
# Out:
# hello
# good morning team
# hello
# good morning team

# %%
def greet():
    print('hello')
    print('good morning team')
greet()

print()

def greet():
    print('hello')
    print('good morning team')
greet()
# Out:
# hello
# good morning team
#
# hello
# good morning team

# %%
def greet():
    print('hello')
    print('good morning team')
greet()

print()

def greet():
    print('hello')
    print('good morning team')
greet()

print()

def greet():
    print('hello')
    print('good morning team')
greet()
# Out:
# hello
# good morning team
#
# hello
# good morning team
#
# hello
# good morning team

# %%
def greet():  #declare function without argument 
    print('hello')
    print('good morning team')

greet()
print('************')
greet()
print('************')
greet() # function calling with out argument
# Out:
# hello
# good morning team
# ************
# hello
# good morning team
# ************
# hello
# good morning team

# %%
# function without argument 

def greet():
    print('hello')
    print('good morning team')
greet()
# Out:
# hello
# good morning team

# %%
# function with argument 

def add(x,y):
    c = x+y
    print(c)
add(5,6)
# Out:
# 11

# %%
# function with argument 

def add(x,y):
    c=x,y
    return c

add(5,6)
# Out:
# (5, 6)

# %%
# function with argument 
def add(x,y):
    c=x+y
    return c
add(5,6)
# Out:
# 11

# %%
# function with argument 

def add(x,y):
    c = x,y
    return c
add(5)  # add() missing 1 required positional argument:'y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       4     c = x,y
#       5     return c
# ----> 6 add(5)  # add() missing 1 required positional argument:'y'
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
# function with argument 

def add(x,y):
    c = x,y
    return c 

add(5,6,7)  # add(0 takes 2 positional arguments but 3 were given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       4     c = x,y
#       5     return c
# ----> 7 add(5,6,7)  # add(0 takes 2 positional arguments but 3 were given
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
# function with argument 

def add(x,y,z):
    c=x,y
    return c
add(5,6,7)
# Out:
# (5, 6)

# %%
# function with argument 

def add(x,y,x):
    c = x,y,z,m
    return c 
add(5,6,7)
# Out:
#   Cell In[21], line 3
#     def add(x,y,x):
#                 ^
# SyntaxError: duplicate argument 'x' in function definition

# %%
# function with argument 
def add(x,y,z,n):
    c = x+y+z+m
    return c
add(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       3     c = x+y+z+m
#       4     return c
# ----> 5 add(5,6,7,8)
#
# Cell In[22], line 3, in add(x, y, z, n)
#       2 def add(x,y,z,n):
# ----> 3     c = x+y+z+m
#       4     return c
#
# NameError: name 'm' is not defined

# %%
# function with argument 
def add(x,y,z,n):
    c = x+y+z+n
    return c
add(5,6,7,8)
# Out:
# 26

# %%
def greet():
    print('hello')
    print("good morning team")
greet()

def add(x,y):
    c = x,y
    return c
add(5,6)
# Out:
# hello
# good morning team
# (5, 6)

# %%
def greet():
    print('hello')
    print("good morning team")

def add(x,y):
    c = x+y
    return c
    
def sub(x,y):
    d = x-y
    return d 

greet()
print(add(5,6))
print(sub(5,6))
# Out:
# hello
# good morning team
# 11
# -1

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c, d
    
result1,result1 = add_sub(4,5)
print(result1)
print(result1)
print(type(result1))
# Out:
# -1
# -1
# <class 'int'>

# %%
def add_sub_mul(x,y):
    c = x+y
    d = x-y
    e = x*y
    return c, d, e 

add, sub, mul = add_sub_mul(4,5)

print(add)
print(sub)
print(mul)
# Out:
# 9
# -1
# 20

# %% [markdown]
# # UPDATE

# %%
def update():
    x = 8
    print(x)
update()
# Out:
# 8

# %%
def update():   # update function take the value from the user 
    x = 8
    print(x)

update(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       2     x = 8
#       3     print(x)
# ----> 5 update(8)
#
# TypeError: update() takes 0 positional arguments but 1 was given

# %%
def update(x):   # update function take the value from the user 
    x = 8
    return x

update(100)
# Out:
# 8

# %%
def update(x):
    x = 8
    return x

a = 15
update(a)
print(a)
# Out:
# 15

# %%
def person(name,age):
    print(name)
    print(age)

person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age):
    print(name)
    print(age)
person(22,'nit')
# Out:
# 22
# nit

# %%
def person(name,age):
    print(name)
    print(age-1)

person(22, 'nit')
# Out:
# 22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 5
#       2     print(name)
#       3     print(age-1)
# ----> 5 person(22, 'nit')
#
# Cell In[47], line 3, in person(name, age)
#       1 def person(name,age):
#       2     print(name)
# ----> 3     print(age-1)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
def person(name,age):
    print(name)
    print(age-1)

person(age=22,name='nit')
# Out:
# nit
# 21

# %%
def person(name,age,new_age):
    print(name)
    print(age-1)
    print(new_age)

person(age = 22,name='nit', new_age=23)
# Out:
# nit
# 21
# 23

# %% [markdown]
# # DEFAULT ARGUMENT

# %%
def person(name, age=18):
    print(name)
    print(age)

person('nit')
# Out:
# nit
# 18

# %%
def person(name,age=18):
    print(name)
    print(age)

person('nit',40)
# Out:
# nit
# 40

# %% [markdown]
# # Variable length argument

# %%
def person(name,age):
    print(name)
    print(age)

person('nit',40,50,60,70,80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit',40,50,60,70,80)
#
# TypeError: person() takes 2 positional arguments but 6 were given

# %%
def sum(a,b):
    c = a+b
    print(c)

sum(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 5
#       2     c = a+b
#       3     print(c)
# ----> 5 sum(5,6,7,8)
#
# TypeError: sum() takes 2 positional arguments but 4 were given

# %%
def sum(a, *b): #1st argument is fixed but for 2nd argument
    # c = a+b
    print(type(a))
    print(type(b))

sum(5,6,7,8)
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
def sum(a, *b): # 1st argument is fixed & we fecth each value from the tuple & we can add them.
    c = a
    for i in b:
        c= c+ i
    print(c)

sum(5,6,7,8)
# Out:
# 26

# %%
def sum(a, *b): # 1st argument is fixed & we fecth each value from the tuple & we can add them.
    c = a
    for i in b:
        c= c+ i
    print(c)

sum(5,6,7,8,9,20)
# Out:
# 55

# %%
def sum(a, *b): # 1st argument is fixed & we fecth each value from the tuple & we can add them.
    c = a
    for i in b:
        c= c+ i
    print(c)

sum(5,6,7,8)
# Out:
# 26

# %% [markdown]
# # Kwargs

# %%
def person():
    person('ALEX',36,'JOHN',987767)

# %%
def person(name, *data):
    print(name)
    print(data)

print('ALEX',36,'JOHN',987767)
# Out:
# ALEX 36 JOHN 987767

# %%
def person(name, **data):
    print('name')
    print(data)

person('ALEX',age = 36,home_place='southcity',mob=987767)
# Out:
# name
# {'age': 36, 'home_place': 'southcity', 'mob': 987767}

# %%
def person(name, **data):
    print('name')
    print(data)

person('ALEX',age = 36,home_place='southcity',mob=987767,salary=40000,married='yes')
# Out:
# name
# {'age': 36, 'home_place': 'southcity', 'mob': 987767, 'salary': 40000, 'married': 'yes'}

# %% [markdown]
# # Functional Argument Completed

# %% [markdown]
# # Global Variable & Local Variable

# %%
a = 10 #---global variable

def something():
    b =15 #local variable

# %%
a = 10 #---global variable 

def something():
    b = 15 # local variable

    print('in function',b)
    print('out function',a)

# %%
a = 10 
def something():
    b = 15
    print('in function',b)

print('out function',a)
# Out:
# out function 10

# %%
a = 10 #---global variable 

def something():
    b = 15 # local variable

print('in function',a)
print('out function',a)
# Out:
# in function 10
# out function 10

# %%
a = 10 #---global variable 

def something():
    b = 15 # local variable
    print('in function',b)  # local variable
something()

print('out function',a)  # global variable
# Out:
# in function 15
# out function 10

# %%
a = 10 #---global variable 

def something():
    # if we remove this variable then can default it consider as global variable
    print('in function',a)

something()
print('out function',a)
# Out:
# in function 10
# out function 10

# %%
a = 10
def something():
    global a 
    b = 15 # 15v is converted to local when user assigned global a
    print('in function',b)
    print('global variable',a)

something()

print('out function',a)
# Out:
# in function 15
# global variable 10
# out function 10

# %%
a = 20 

def something():
    global a 
    a = 15
    print('in function',a)

    a = 15

something()
print('out function',a)
# Out:
# in function 15
# out function 15

# %%
x = 10  # global variable

def update_x():
    global x # Declare that we are using the global variable x 
    x += 5 # Modify the global variable 

update_x()
print(x)   # output :15
# Out:
# 15

# %%
x = 10 # Global varaible 

def update_x():
    globals()['x'] += 5 #access and modify the global variable using the dictionary 

update_x()
print(x)  # ouput :15
# Out:
# 15
