# %%
import numpy as np # NumPy

# %%
import matplotlib.pyplot as plt # Visulization

# %%
from PIL import Image # python image library

# %%
feature_image = Image.open(r'C:\Users\Dell\Downloads\Rohit Sharma.jpg')

# %%
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x180>

# %%
myimage = Image.open(r'C:\Users\Dell\Downloads\Rohit Sharma.jpg')

# %%
myimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x180>

# %%
print(type(feature_image))
print(type(myimage))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
fea_arr = np.asarray(feature_image)
fea_arr
# Out:
# array([[[ 24,  32,  45],
#         [ 21,  29,  40],
#         [ 16,  24,  35],
#         ...,
#         [  5,   5,  15],
#         [  7,   5,  18],
#         [  7,   5,  19]],
#
#        [[ 20,  28,  41],
#         [ 17,  25,  36],
#         [ 13,  21,  32],
#         ...,
#         [  4,   4,  14],
#         [  4,   4,  16],
#         [  4,   3,  17]],
#
#        [[ 14,  22,  35],
#         [ 12,  20,  31],
#         [  9,  17,  28],
#         ...,
#         [  2,   2,  12],
#         [  2,   2,  14],
#         [  3,   2,  16]],
#
#        ...,
#
#        [[155, 135, 136],
#         [159, 139, 141],
#         [165, 146, 150],
#         ...,
#         [187, 189, 188],
#         [198, 198, 196],
#         [204, 203, 199]],
#
#        [[142, 120, 122],
#         [146, 126, 128],
#         [152, 133, 137],
#         ...,
#         [182, 184, 183],
#         [194, 194, 192],
#         [200, 199, 195]],
#
#        [[134, 112, 114],
#         [138, 118, 120],
#         [144, 125, 129],
# ...

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape
# Out:
# (180, 320, 3)

# %%
my_arr = np.asarray(myimage)
my_arr
# Out:
# array([[[ 24,  32,  45],
#         [ 21,  29,  40],
#         [ 16,  24,  35],
#         ...,
#         [  5,   5,  15],
#         [  7,   5,  18],
#         [  7,   5,  19]],
#
#        [[ 20,  28,  41],
#         [ 17,  25,  36],
#         [ 13,  21,  32],
#         ...,
#         [  4,   4,  14],
#         [  4,   4,  16],
#         [  4,   3,  17]],
#
#        [[ 14,  22,  35],
#         [ 12,  20,  31],
#         [  9,  17,  28],
#         ...,
#         [  2,   2,  12],
#         [  2,   2,  14],
#         [  3,   2,  16]],
#
#        ...,
#
#        [[155, 135, 136],
#         [159, 139, 141],
#         [165, 146, 150],
#         ...,
#         [187, 189, 188],
#         [198, 198, 196],
#         [204, 203, 199]],
#
#        [[142, 120, 122],
#         [146, 126, 128],
#         [152, 133, 137],
#         ...,
#         [182, 184, 183],
#         [194, 194, 192],
#         [200, 199, 195]],
#
#        [[134, 112, 114],
#         [138, 118, 120],
#         [144, 125, 129],
# ...

# %%
plt.imshow(my_arr)
plt.show()

# %%
my_arr.shape
# Out:
# (180, 320, 3)
